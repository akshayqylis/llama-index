# %%
from pathlib import Path

# %%
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import (
    PdfPipelineOptions,
    TesseractCliOcrOptions,
)
from docling.document_converter import DocumentConverter, PdfFormatOption

# %%
input_doc = Path("Commercial Policy.pdf")

pipeline_options = PdfPipelineOptions()
pipeline_options.do_ocr = True
pipeline_options.do_table_structure = True
pipeline_options.table_structure_options.do_cell_matching = True

# Any of the OCR options can be used:EasyOcrOptions, TesseractOcrOptions, TesseractCliOcrOptions, OcrMacOptions(Mac only), RapidOcrOptions
# ocr_options = EasyOcrOptions(force_full_page_ocr=True)
# ocr_options = TesseractOcrOptions(force_full_page_ocr=True)
# ocr_options = OcrMacOptions(force_full_page_ocr=True)
# ocr_options = RapidOcrOptions(force_full_page_ocr=True)
ocr_options = TesseractCliOcrOptions(force_full_page_ocr=True)
pipeline_options.ocr_options = ocr_options

converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(
            pipeline_options=pipeline_options,
        )
    }
)

doc = converter.convert(input_doc).document
md = doc.export_to_markdown()
print(md)
# Out:
# <!-- image -->
#
# <!-- image -->
#
# ## COMMERCIAL POLICY CHANGE REQUEST
#
# <!-- image -->
#
# Page 1 of 2
#
# © 1991-2015 ACORD CORPORATION.
#
# 19 fe | 9025
#
# CARRIER
#
# AGENCY
#
# ATTENTION
#
# POLICY NUMBER
#
# [ Si. | 2 uy 4
#
# ACCOUNT NUMBER
#
# 99296 GS2 jOO0¢Q
#
# EFFECTIVE DATE OF CHANGE [ 5 OF] 2025
#
# POLICY INCEPTION DATE
#
# \_
#
# POLICY EXPIRATION DATE
#
# CONTACT
#
# ADONESS:
#
# eee
#
# iam
#
# cove:
#
# S023.
#
# SUBCODE:
#
# lle
#
# [20
#
# as
#
# 2]
#
# ©€[
#
# 202)
#
# AGENCY CUSTOMER BD:
#
# Poucy
#
# PROPERTY
#
# ‘AUTO
#
# |\_\_|
#
# workers comp
#
# NAMED INSURED
#
# INLAND MARINE
#
# TRUCKERS:
#
# UMBRELLA |\_|
#
# Motor carriers
#
# |\_|
#
# INSURED'S
#
# NAME
#
# AND
#
# MAILING
#
# ADDRESS,
#
# IF
#
# CHANGED
#
# (INC
#
# ZiPr4)
#
# GENERAL LeiuiTy
#
# |\_|
#
# BusINEss
#
# owners
#
# |]
#
# THIS IS AN ACKNOWLEDGEMENT OF YOUR REQUEST. UPON APFROVAL, THE COMPANY'S RECORDS WILL BE ADJUSTED ACCORDINGLY, AND IF A PREMIUM ADJUSTMENT IS REQUIRED, IT WILL BE DONE AT PREMIUM AUDIT OR BY ENDORSEMENT.
#
# Ajay»
#
# Gachibewl?
#
# +ydera
#
# CITY LIMITS
#
# INSIDE
#
# OUTSIDE
#
# INTEREST
#
# OWNER
#
# DELETE
#
# Loc #
#
# BLD?
#
# DELETE
#
# ci
#
# 1
#
# SYM/
#
# AGE
#
# OTC
#
# SYM|
#
# SYM
#
# ## AUTO-VEHIGLE DESGRIPTION/ LIMITS
#
# [|\_\_|
#
# rouicyumms)cnance&gt;——=SSS™S*~*d
#
# YEAR
#
# |
#
# MAKE:
#
# Freee
#
# VEHICLE
#
# TYPE
#
# MODEL:
#
# V.LNG:
#
# PP
#
# SPEC
#
# COML
#
# GARAGING
#
# |
#
# STREET
#
# (Requirad
#
# in
#
# KY)
#
# cry
#
# d
#
# COUNTY
#
# STATE
#
# |
#
# ZIP
#
# .
#
# scores
#
# |
#
# Chachhibewl!
#
# devoba
#
# tds a
#
# TS
#
# |
#
# §o%303
#
# gee
#
# TERR
#
# GVW/GCW
#
# CLASS
#
# SIC
#
# FACTOR
#
# |SEATCP}
#
# RADIUS
#
# FARTHEST TERMINAL
#
# COST
#
# NEW
#
# $
#
# f
#
# ADD'LNO-|
#
# |
#
# UNDRINS
#
# RENT
#
# 2
#
# COMP],
#
# SPEC
#
# USE
#
# COMML
#
# FOR
#
# HIRE
#
# ADDI
#
# Hi
#
# NDRIN
#
# F
#
# LSP
#
# E
#
# RENT
#
# |
#
# DEDUCTIBLES
#
# acy|\_\_[°SMPT
#
# SPEC
#
# |
#
# PLeasuRE
#
# en
#
# MED
#
# PAY
#
# TOWING!
#
# FT
#
# SOMP/
#
# FG
#
# AA
#
# stamt
#
# |§
#
# 7
#
# UNINS
#
# SPEC
#
# |
#
# FARM
#
# SERVICE
#
# HNINS
#
# a58.
#
# FTw
#
# COLL
#
# $
#
# $
#
# DRIVETO
#
# WORK
#
# /
#
# SCHOO!
#
# =c
#
# POLICY
#
# LIMIT(S)
#
# CHANGED
#
# iia
#
# BODY
#
# MAKE:
#
# TYPE:
#
# VEHICLE
#
# TYPE
#
# SYM/
#
# AGE
#
# /oGoMh
#
# ty
#
# 2003}
#
# move:
#
# VolNs
#
# [
#
# ]er
#
# [spec
#
# [~
#
# |
#
# com
#
# GARAGING
#
# |
#
# STREET
#
# (Required
#
# in
#
# KY)
#
# cry
#
# COUNTY
#
# STATE
#
# |
#
# ZIP
#
# =
#
# apur
#
# Hydereboad
#
# (wDrA
#
# TS
#
# 504303
#
# orate
#
# TERR
#
# VW
#
# |
#
# GCW
#
# CLASS
#
# sic
#
# FACTOR
#
# |SEATGP|
#
# RADIUS
#
# FARTHEST
#
# TERMINAL
#
# COST
#
# NEW
#
# al
#
# a
#
# s
#
# Use
#
# COMML
#
# FORHIRE
#
# |
#
# CHECK
#
# oes
#
# pavers
#
# PRDRINS
#
# F
#
# |
#
# [use
#
# REN],
#
# \_
#
# |
#
# DEDUCTIBLES
#
# acy]
#
# |°OHPI]
#
# A
#
# ensies
#
# ||
#
# neta
#
# uns
#
# [Aweoear
#
# [|
#
# sommes
#
# [er
#
# [|
#
# gover
#
# ee
#
# wm
#
# Aeron
#
# ETS
#
# SERVICE
#
# Fao
#
# UNINS.
#
# SE.
#
# FTW
#
# COLL
#
# $
#
# Seno,
#
# &lt;
#
# 15
#
# MILES
#
# tsmiles+
#
# |
#
# NETVE
#
# TORR
#
# LIABILITY
#
# NO FAULT
#
# UNINSURED MOTORISTS
#
# \_
#
# x
#
# SOCIAL
#
# SECUNTY
#
# NUMBER
#
# HIRE
#
# \_|orau
#
# vor
#
# =
#
# ——
#
# x
#
# =
#
# =.
#
# * MARITAL STATUS / CIVIL UNION (If applicable)
#
# ACORD 175 (2016/03)
#
# All rights reserved. The ACORD name and logo are registered marks of ACORD
#
# DATE (MMI/DD/YYYY)
#
# WORKERS COMPENSATION RATING INFORMATION
#
# AGENCY CUSTOMER ID:
#
# ## Se Ti 6 sas ee
#
# <!-- image -->
#
# ESTIMATED ANNUAL REMUNEDATION
#
# TYPE
#
# OF
#
# 3 GLASSCODE
#
# DESCR ‘cope
#
# CHANGE)
#
# STATE
#
# |
#
# Loc
#
# |
#
# |
#
# CATEGORIES, DUTIES, CLASSIFICATIONS
#
# PROPERTY
#
# /
#
# INLAND
#
# MARINE
#
# -
#
# PREMISES
#
# INFORMATION
#
# \_\_|premises#:
#
# \_\_|eunonc#:
#
# |
#
# |
#
# \_[aop
#
# \_\_|
#
# \_|
#
# cHANGE
#
# DELETE
#
# NFLATIO
#
# SUBJECT
#
# OF
#
# INSURANCE
#
# AMOUNT
#
# COINS%
#
# |VALUATION|
#
# CAUSES
#
# OF
#
# LOSS
#
# TSUARD:
#
# |
#
# DEDUCTIBLE
#
# FORMS
#
# AND
#
# CONDITIONS
#
# TO
#
# APPLY
#
# ‘ADDITIONAL COVERAGES, OPTIONS, RESTRICTIONS, ENDORSEMENTS AND RATING INFORMATION (Attach ACORD 101, Additional Remarks Schedule, if more space is required)
#
# ~
#
# DISTANCE TO HYDBSTANCETO |
#
# CONSTRUCTION TYPE
#
# FIREDISTRICT/ CODE NUMBER
#
# |
#
# PROTCL
#
# |#STORIES|#BASMTS|
#
# YRBUILT
#
# |
#
# TOTALAREA
#
# |
#
# fad
#
# MI
#
# \_
#
# ILDING IMPROVEMENTS
#
# PLUMBING,
#
# YR:
#
# BLOG CODE
#
# —INSFEGT=D?|
#
# ROOF
#
# |
#
# OTHER OCCUPANCIES
#
# "
#
# sail
#
# WIRING, YR:
#
# |\_|
#
# HEATING, YR:
#
# \_\_| RIGHT EXPOSURE &amp; DISTANCE
#
# ROOFING, YR:
#
# |
#
# \_\_lotHer:
#
# TAXCODE
#
# OG |
#
# LEFT EXPOSURE &amp; DISTANCE
#
# REAR EXPOSURE &amp; DISTANCE
#
# BURGLAR ALARM TYPE
#
# CERTIFICATE #
#
# EXPIRATION DATE
#
# EXTENT
#
# |
#
# GRADE
#
# CETRAU
#
# STATION
#
# rE
#
# 06 | o6| 2020
#
# WITH KEYS
#
# BURGLAR ALARM INSTALLED AND SERVICED BY
#
# # GUARDSIWATCHMEN
#
# eLbGK HOURLY
#
# PREMISES FIRE PROTECTION (Sprinklers, Standpipes, CO, / Chemical Systems)
#
# FIRE ALARM MANUFACTURER
#
# CENTRAL STATION
#
# LOCAL GONG.
#
# ## INLAND MARINE - SCHEDULED EQUIPMENT
#
# [wconsurance:
#
# «|
#
# Ss
#
# —sdtap&gt;
#
# «|\_|
#
# CHANGE
#
# DELETE
#
# DESCRIPTION
#
# (TYPE,
#
# MANUFACTURER,
#
# MODEL,
#
# CAPACITY,
#
# ETC)
#
# ID#ISERIAL#
#
# PURAIASED
#
# |
#
# NEW/USED
#
# ARCANE
#
# |
#
# s
#
# {£060
#
# s
#
# (€000
#
# ## GENERAL LIABILITY - LIMITS
#
# CHANGE
#
# |
#
# GENERAL AGGREGATE
#
# eee
#
# ies
#
# $
#
# DAMAGE TO RENTED PREMISES
#
# |
#
# PRODUCTS &amp; COMPLETED C/PERATIONS AGGREGATE
#
# $
#
# MEDICAL EXPENSE (Any one person)
#
# PERSONAL &amp; ADVERTISING INJURY
#
# \_\_
#
# EMPLOYEE BENEFITS
#
# EACH OCCURRENCE
#
# $
#
# CLASSIFICATION
#
# CLASS
#
# PREMIUM
#
# EXPOSURE
#
# TERR
#
# PREMIUM BASIS CODES
#
# CODE
#
# (S) GROSS SALES - PER $1,000/SALES
#
# (P) PAYROLL - PER $i1,000/PAY
#
# (A) AREA - PER 1,000/SQ FT
#
# (C) TOTAL COST - PEER $1,000/COST (M) ADMISSIONS -
#
# PER
#
# 4,000/ADM
#
# (U) UNIT - PER UNIT
#
# (1)
#
# OTHER
#
# UMBRELLA
#
# LIMITOF LIABILITY
#
# $
#
# RETAINED LIMIT
#
# s
#
# ADDITIONAL INTEREST
#
# INTEREST
#
# OTHER
#
# (DESCRIBE)
#
# DELETE
#
# INTEREST IN ITEM NUMBER
#
# Levoence: cermiricare
#
# |\_\_|
#
# |
#
# NAME AND ADDRESS RANK:
#
# ADDITIONAL
#
# INSURED EMPLOYEE AS LESSOR
#
# LOSS PAYEE
#
# LOCATION:
#
# BUILDING:
#
# MORTGAGEE
#
# VEHICLE:
#
# BOAT:
#
# |
#
# LENDER'
#
# OWNER
#
# | LOSS PAYABLE! LIENHOLDER
#
# \_|
#
# AIRPORT:
#
# REGISTRANT
#
# mEMIGEAGS.
#
# ITEM DESCRIPTION
#
# REFERENCE / LOAN #:
#
# jon in coverage re uires the Insured's signature
#
# PRODUCER'S NAME (Please Print)
#
# (ODUCER LICENSE NO TATE PR (Required In Florida)
#
# PRODUCER'S SIGNATURE
#
# J
#
# INSURED'S SIGNATURE
#
# NATIONAL PRODUCER NUMBER
#
# PRODUCER'S NAME (Please Print)
#
# (ODUCER LICENSE NO TATE PR (Required In Florida)
#
# PRODUCER'S SIGNATURE
#
# J
#
# INSURED'S SIGNATURE
#
# NATIONAL PRODUCER NUMBER
#
# ACORD
#
# 175
#
# (2016/03)
#
# Page 2 of 2
#
# <!-- image -->

# %%
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.document_converter import (
    ConversionResult,
    DocumentConverter,
    InputFormat,
    PdfFormatOption,
)
from docling_ocr_onnxtr import OnnxtrOcrOptions


def main():
    # Source document to convert
    source = "Commercial Policy.pdf"

    # Available detection & recognition models can be found at
    # https://github.com/felixdittrich92/OnnxTR

    # Or you choose a model from Hugging Face Hub
    # Collection: https://huggingface.co/collections/Felix92/onnxtr-66bf213a9f88f7346c90e842

    ocr_options = OnnxtrOcrOptions(
        # Text detection model
        det_arch="db_mobilenet_v3_large",
        # Text recognition model - from Hugging Face Hub
        reco_arch="Felix92/onnxtr-parseq-multilingual-v1",
        # This can be set to `True` to auto-correct the orientation of the pages
        auto_correct_orientation=False,
    )

    pipeline_options = PdfPipelineOptions(
        ocr_options=ocr_options,
    )
    pipeline_options.allow_external_plugins = True  # <-- enabled the external plugins

    # Convert the document
    converter = DocumentConverter(
        format_options={
            InputFormat.PDF: PdfFormatOption(
                pipeline_options=pipeline_options,
            ),
        },
    )

    conversion_result: ConversionResult = converter.convert(source=source)
    doc = conversion_result.document
    md = doc.export_to_markdown()
    print(md)


if __name__ == "__main__":
    main()
# Out:
# Downloading https://github.com/felixdittrich92/OnnxTR/releases/download/v0.2.0/db_mobilenet_v3_large-4987e7bd.onnx to /home/akshaymambakam/.cache/onnxtr/models/db_mobilenet_v3_large-4987e7bd.onnx
# 16077824it [00:02, 7163358.25it/s]
# <!-- image -->
#
# ACORD 175 (2016/03)
#
# AGENCY
#
# !ź/#\_ /2ø¿$
#
# CARRIER
#
# NAIC CODE
#
# ATTENTION
#
# 9.b
#
# CONIACT.
#
# POLICY! NUMBER
#
# NAME:
#
# |}~
#
# PHONE.
#
# Ł %&amp;'( {\_ô\_ £
#
# 12-144
#
# LAIç,-no,Æ Ext):\_
#
# ACCOUNT NUMBER
#
# FAX.
#
# ¥45.! Noì:\_
#
# ]^\_ 9
#
# 'iv 24 ylabiubì empu mi
#
# 1132645210072
#
# ADDRESS:\_
#
# EFFECTIVE DĄTE OF( CHANGE 6 |0+ 2025
#
# POLICY! INCEPTIONI DATE
#
# CODE;
#
# Te2.ï 3
#
# SUBCODE:
#
# 2./:
#
# POLICY,EXPIRATION.D DATE
#
# lo
#
# 6
#
# 2ebi
#
# lx
#
# AGENCYC CUSTOMERI ID;
#
# POLICY TYPE
#
# PROPERTY
#
# AUTO.
#
# °6|
#
# 2o)2
#
# NAMEDI INSURED
#
# WORKERS comp
#
# INLANDI MARINE
#
# TRUCKERS
#
# unshine
#
# UMBRELLA
#
# kawiin
#
# MOTOR CARRIERS
#
# Żicckton.ì&lt;
#
# INSURED'S
#
# NAME/
#
# ANDI
#
# MAILING./
#
# ADDRESS,!
#
# IFA
#
# CHANGED
#
# (INCZ
#
# CZIP+4)
#
# GENERALI LIABILITY
#
# BUSINESS
#
# OWNERS
#
# Å
#
# THIS IS AN. ACKNOWLEDGEMENT OF YOUR REQUEST. UPON APFROVAL, THE COMPANY'S RECORDS WILL BE ADJUSTED ACCORDINGLY,\_ AND\_ IF A PREMIUM. ADJUSTMENT IS ¡ITI WILLI BEI DONE. REQUIRED,! AT PREMIUM, AUDIT ORI BY ENDORSEMENT.
#
# Gachì|öÄî
#
# #4##ç.í%[!
#
# Aja9
#
# SHORT
#
# DESCRIPTION\_
#
# OF
#
# CHANGES
#
# /REMARKS
#
# (ACORD
#
# 101,
#
# Additiona|
#
# Remarks
#
# Schedule,
#
# may\_
#
# be\_
#
# attached
#
# ¡fi
#
# more.
#
# space
#
# is\_
#
# required)
#
# ## PREMISES INFORMATION
#
# ADD\_
#
# LOC#
#
# BLD#\_
#
# STREET,( CITY, COUNTY,! STATE,2 ZIP+4
#
# CITYL LIMITS
#
# INTEREST
#
# CHANGE\_
#
# DELETE
#
# YRI BUILT
#
# PART OCCUPIED
#
# INSIDE
#
# OWNER
#
# OUTSIDE
#
# TENANT
#
# ## NATURE OF BUSINESS / DESCRIPTION OF OPERATIONS BY PREMISE(S)
#
# ADD\_
#
# LOC#
#
# BLD#
#
# CHANGE
#
# DELETE
#
# ## AUTO-VEHICLE DESCRIPTION /1 LIMITS\_
#
# POLICY!
#
# LIMIT(S)
#
# CHANGED
#
# VEH#
#
# YEAR
#
# MAKE:
#
# ADD\_
#
# CHANGE\_
#
# DELETE
#
# FREX\_
#
# VEHICLE
#
# TYPE
#
# SYM/
#
# AGE|
#
# coll
#
# MODEL:
#
# VII.N.:\_
#
# ¡sersap
#
# šÝM
#
# GARAGING
#
# STREET
#
# (Requiredi
#
# in.ł
#
# KY)
#
# CITY
#
# PP
#
# SPEC
#
# COML
#
# ADDRESS
#
# ď1@[\ìĎ0WÍ
#
# Hypbemal
#
# COUNTY
#
# øl Indi
#
# STATE
#
# ZIP
#
# \_LIC\_
#
# 7
#
# c
#
# STATE
#
# TERR
#
# GVW/ť Gcw
#
# Je33o3
#
# class
#
# SIC
#
# FACTOR\_
#
# SEAT
#
# cp|
#
# RADIUS
#
# FARTHEST1 TERMINAL
#
# COST
#
# NEW
#
# USE
#
# COMM'L
#
# FORI
#
# HIRE
#
# COVERAGES
#
# CHECK
#
# FAULT'
#
# ADD'LI
#
# ¡no-|
#
# \_F
#
# LSP
#
# RENT
#
# DEDUCTIBLES
#
# $
#
# |COMP/|
#
# PLEASURE
#
# RETAIL.
#
# L'EITERT
#
# TOWING
#
# REIMB
#
# AC:V|
#
# SPEC
#
# LIAB
#
# MEDI
#
# PAY
#
# &amp;LABOR
#
# FT
#
# COMP/
#
# FG
#
# otcí
#
# č
#
# :õfl
#
# FARM
#
# SERVICE
#
# UNINS\_
#
# õÝč"
#
# AA
#
# STI
#
# 'AMT
#
# $
#
# DRIVE1
#
# T2.
#
# MIEL
#
# NE
#
# T'
#
# Motor\_
#
# 8259
#
# FTW
#
# COLL
#
# $
#
# $
#
# WORK
#
# ¿school.
#
# &lt;15MILES
#
# 15I
#
# MILES
#
# )R/CR;
#
# VEH
#
# COLL
#
# LIABILITY
#
# NO.FAULT
#
# ADD'LNO.F FAULT\_
#
# TOTALI
#
# .PREM:\_
#
# $
#
# MEDICALI
#
# PAYMENTS\_
#
# UNINSUREDI MOTORISTS
#
# UNDERINSURED.MOTORISTS\_
#
# ## AUTO-VEHICLE DESCRIPTION LIMITS\_ VEH# YEAR
#
# $
#
# $
#
# POLICYL
#
# LIMIT(S)
#
# CHANGED
#
# MAKE:\_
#
# BODY
#
# ADD\_
#
# CHANGE
#
# DELETE
#
# Il
#
# ¿ee
#
# c3|
#
# MODEL:\_
#
# TYPE:\_
#
# VEHIGLE`
#
# TYPE
#
# SYM/
#
# AGE|
#
# |òřč"
#
# COMP,
#
# "svív|
#
# VILN,;
#
# "EREF
#
# GARAGING
#
# STREET(
#
# (Requirexli
#
# int
#
# ¡KY)
#
# CITY
#
# PP
#
# SPEC
#
# COML
#
# ADDRESS
#
# COUNTY
#
# V
#
# lovdy
#
# Expur
#
# SITATE
#
# ZIP
#
# LIC\_
#
# tijderxloa,d
#
# STATE
#
# TERR
#
# dvw/ccw=
#
# CLASS
#
# SIC
#
# In
#
# ILI
#
# T9
#
# 15e303
#
# FACTOR
#
# SEAT
#
# cp|
#
# RADIUS
#
# FARTHEST1
#
# TERMINAL
#
# COST
#
# NEW
#
# USE
#
# COMM'L
#
# FORI
#
# HIRE
#
# CHECK.
#
# ADDILN
#
# -no-|
#
# UNDRINS
#
# S
#
# PLEASURE
#
# RETAIL
#
# COVERAGES
#
# Fxult
#
# Motor``
#
# F
#
# LSP
#
# REIMB
#
# RENT
#
# DEDUCTIBLES
#
# SPĘC
#
# LIAB
#
# MEDI
#
# PAY
#
# FT
#
# FG
#
# ACV|\_
#
# 1845\_
#
# ci
#
# OFI
#
# FARM
#
# SERVICIE
#
# |ž=&gt;?
#
# UNINS
#
# AA
#
# SPI
#
# 89'%
#
# ST,
#
# AMT
#
# \_$\_
#
# °
#
# DRIVE1
#
# LT
#
# MOTOR\_
#
# COFL
#
# FTW
#
# COLL
#
# work
#
# &lt;15.MILES
#
# 15.MILES-
#
# TI
#
# "VEH
#
# $
#
# \_`{|}\_
#
# ODÓ
#
# NET
#
# /CR:
#
# COLL
#
# LIABILITY\_
#
# NOFAULT
#
# ADD'LI NO FAULT
#
# TOTALI
#
# PREM:\_
#
# $
#
# £)\_
#
# MEDICAL| PAYMENTS
#
# UNINSUREDI MOTORISTS
#
# UNDIERINSURED.MOTORISTS
#
# DRIVER|
#
# DRIVERI
#
# INFORMATION\_
#
# (List\_
#
# drivers\_
#
# who
#
# frequently
#
# use\_
#
# own
#
# $
#
# NAME
#
# "MART
#
# vehicles)\_
#
# ADD\_
#
# CHANGE\_
#
# CITY,.STATE.AND\_
#
# ZIP\_C
#
# CODE
#
# SEX
#
# STAT\_
#
# DATE(
#
# OFE
#
# BIRTH
#
# Í%#$]
#
# |YEAR|
#
# \_
#
# DRIVERST
#
# ¿LICENSENUMBER
#
# DATE
#
# "PADEN]
#
# DIELETE\_
#
# USE.
#
# SOCIAL.SECURITY
#
# NUMBER\_
#
# )*+,Ť=
#
# HIRE\_
#
# 104
#
# FAULT|\_[
#
# poc|
#
# VEH#
#
# .USE\_
#
# MARITAL. STATUS/( CIVILI UNION (if, applicable)
#
# The
#
# ## COMMERCIAL POLICY CHANGE REQUEST
#
# <!-- image -->
#
# Page 1 of. 2
#
# @ 1991-2015 ACORD CORPORATION.
#
# AII rights reserved. ACORD name and logo are registered marks of ACORD
#
# <!-- image -->
#
# DATĘ( ammuquprvyyx
#
# WORKERS COMPENSATION RATING INFORMATION
#
# AGENCY CUSTOMER ID:\_
#
# ## 5IT672.Ť419
#
# <!-- image -->
#
# OF
#
# ESTIMATED ANNUAL\_ REMUNERATION
#
# |CHANGE|
#
# TYPE!
#
# OF
#
# STATE
#
# LOC
#
# GLASS CODE
#
# DESCR CODE`
#
# CATEGORIES, DUTIES, CLASSIFICATIONS
#
# FUL IMPLI \_ QYEE, PAR \_TIME.| TIME.
#
# PROPERTY
#
# INLA
#
# ANID
#
# MARINE
#
# PREMISES
#
# INFORMATION
#
# PREMISES
#
# #:\_
#
# BUILDING#:\_
#
# ADD\_
#
# CHANGE
#
# DELETE\_
#
# SUBJECT
#
# OFI
#
# INSURANCE
#
# AMOUNT\_
#
# COINS%\_
#
# |VALUATION
#
# CAUSES
#
# OFI
#
# LOSS
#
# |\_GUARD\_%\_|
#
# INFL
#
# "LATIONT
#
# DEDUCTIBLE
#
# FORMS/
#
# AND
#
# CONDITIONS
#
# TO,
#
# APPLY\_
#
# ADDITIONAL COVERAGES, OPTIONS, RESTRICTIONS,! ENDORSEMENTS. AND RATING! INFORMATION (Attach. ACORD 101,/ Additionall Remarks Schedule, ¡fr more space ¡si required)
#
# CONSTRUCTION1 TYPE
#
# HYDRANT^ JISTANCETO. FIRE. ESTAT
#
# FIREI DISTRICT/ CODE NUMBER
#
# PROT CL
#
# #STORIES
#
# #1 BASM'TS|
#
# YRI BUILT
#
# TOTAL/ AREA
#
# FT|
#
# MI|
#
# BUILI DING IMPROVEMENTS
#
# PLUMBING,' YR:
#
# BLDG ÜBERGEPE
#
# INSPECTED?| YIN
#
# 49PE
#
# OTHER OCCUPANCIES
#
# WIRING,' YR:
#
# HEATING,` YR:
#
# ROOFING,' YR:\_
#
# OTHER:\_
#
# TAX CODE
#
# Ô 32\_\_\_\_\_\_\_\_\_\_
#
# RIGHTI EXPOSURE. &amp;[ DISTANCE
#
# LEFTI EXPOSURE.&amp; &amp; DISTANCE
#
# REARI EXPOSURE &amp;ï DISTANCE
#
# BURGLAR/ ALARM1 TYPE
#
# CERTIFICATE#
#
# EXPIRATION. DATE
#
# EXTENT
#
# GRADE
#
# CENTRAL!
#
# STATION
#
# 06|06|203D
#
# WITH KEYS\_
#
# BURGLAR/ ALARMI INSTALLE:D AND SERVICEDI BY
#
# #GUARDSIWATCHMEN
#
# CLOCKI HOURLY
#
# PREMISES1 FIRE PROTECTION (Sprinklers,: Standpipes,( co¿/ç Chemical. Systems)
#
# FIREALARMI MANUFACTURER
#
# CENTRAL STATION
#
# LOCAL GONG
#
# ## INLAND MARINE SCHEDULED EQUIPMENT\_
#
# %COINSURANCE:
#
# ADD\_
#
# CHANGE
#
# DELETE\_
#
# M8SEI-\_
#
# DESCRIPTION
#
# (TYPE,I
#
# MANUFACTURER,
#
# MODEL,
#
# CAPACITY,!
#
# ETC)
#
# ID#
#
# #SERIAL.#
#
# .#
#
# PURCHASED
#
# DATE
#
# NEW/USED
#
# INSURANCE AMOUNTOF
#
# $
#
# 15oo0
#
# $
#
# (@ööÖ
#
# ## GENERAL LIABILITY\_ LIMITS
#
# CHANGE
#
# GENERAL/ AGGREGATE
#
# $
#
# DAMAGE\_ TOI RENTEDI PREMISES
#
# PRODUCTS &amp; completed CIPERATIONS. AGGREGATE
#
# MEDICAL EXPENSE (Any one¡ person)\_
#
# S
#
# PERSONAL¡ &amp; ADVERTISING INJURY
#
# $
#
# EMPLOYEE.ł BENEFITS
#
# s
#
# EACH OCCURRENCE
#
# $
#
# S
#
# ## GENERAL LIABILITY " SCHEDULE OF HAZARDS
#
# TYPE(
#
# CHANGE
#
# OF
#
# LOC
#
# #
#
# HAZ
#
# ¥
#
# CLASSIFICATION
#
# CLASS
#
# PREMIUM
#
# BASIS
#
# EXPOSURE
#
# TERR
#
# PREMIUMI BASIS CODES
#
# CODE
#
# (S) GROSS SALE ES-- PER.$1,000/SALES
#
# (P) PAYROLL PER' 551,000/PAY
#
# (A) AREA-í PER' 1,000/SQI !FT
#
# (C) TOTAL! COST-I PI:R$ 111000/COST (M), ADMISSIONS-í PER. 1.000/ADM
#
# (U) UNIT PER UNIT (T) OTHER
#
# UMBRELLA
#
# CHANGE\_
#
# LIMIT OFI LIABILITY\_
#
# OTHER\_
#
# RETAINED.LIMIT
#
# §\_
#
# (DESCRIBE)
#
# ADDITIONAL INTEREST
#
# ADD\_
#
# CHANGE
#
# DELETE\_
#
# INTEREST
#
# NAME. AND. ADDRESS RANK:
#
# EVIDENCE:
#
# CERTIFICATE
#
# INTERESTI INI ITEMI NUMBER
#
# ADDITIONAL
#
# INSURED\_ EMPLOYEE ASL LESSOR LENDER'
#
# LOSS PAYEE
#
# LOCATION:\_
#
# BUILDING:\_
#
# MORTGAGEE
#
# VEHICLE:
#
# BOAT:\_
#
# LOSSI PAYABLE| LIENHOLDER
#
# OV/NER
#
# AIRPORT:
#
# REGISTRANT
#
# ITEM\_ GLASS:\_
#
# ITEM:\_
#
# ITEMI DESCRIPTION
#
# REFERENCE /LOAN.#:\_
#
# SIGNATURE (Any deletion. ori reduçtion\_ in coverage requires the Insured's\_ signature) EXPF
#
# PRODUCER'Sś SIGNATURE
#
# ¡UA
#
# IU\
#
# PRODUCER'S NAME (Please\_l Print)
#
# STATEPRODUCERI 'LICENSEI NO (Requlred Inni Florida)"
#
# il
#
# DY
#
# INSURED'S.S SIGNATURE
#
# \_`{|}~.ł\_
#
# 24b8\_
#
# NATIONALI PRODUCERI NUMBER
#
# ~
#
# PRODUCER'Sś SIGNATURE
#
# ¡UA
#
# IU\
#
# PRODUCER'S NAME (Please\_l Print)
#
# STATEPRODUCERI 'LICENSEI NO (Requlred Inni Florida)"
#
# il
#
# DY
#
# INSURED'S.S SIGNATURE
#
# \_`{|}~.ł\_
#
# 24b8\_
#
# NATIONALI PRODUCERI NUMBER
#
# ~
#
# ACORD
#
# 175
#
# (2016/Ď3)
#
# Page 2 of 2
#
# ----
#
# <!-- image -->
